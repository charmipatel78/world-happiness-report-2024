# %% [markdown]
# Title: Global Happiness Report Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Documents\\Datasets\\World-happiness-report-2024.csv")
# Out:
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...

# %%
df=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Documents\\Datasets\\World-happiness-report-2024.csv")
print(df)
# Out:
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   Regional indicator            143 non-null    object
#  2   Ladder score                  143 non-null    float64
#  3   upperwhisker                  143 non-null    float64
#  4   lowerwhisker                  143 non-null    float64
#  5   Log GDP per capita            140 non-null    float64
#  6   Social support                140 non-null    float64
#  7   Healthy life expectancy       140 non-null    float64
#  8   Freedom to make life choices  140 non-null    float64
#  9   Generosity                    140 non-null    float64
#  10  Perceptions of corruption     140 non-null    float64
#  11  Dystopia + residual           140 non-null    float64
# dtypes: float64(10), object(2)
# ...

# %%
print(df.head())
# Out:
#   Country name            Regional indicator  Ladder score  upperwhisker  \
# 0      Finland                Western Europe         7.741         7.815
# 1      Denmark                Western Europe         7.583         7.665
# 2      Iceland                Western Europe         7.525         7.618
# 3       Sweden                Western Europe         7.344         7.422
# 4       Israel  Middle East and North Africa         7.341         7.405
#
#    lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# 0         7.667               1.844           1.572                    0.695
# 1         7.500               1.908           1.520                    0.699
# 2         7.433               1.881           1.617                    0.718
# 3         7.267               1.878           1.501                    0.724
# 4         7.277               1.803           1.513                    0.740
#
# ...

# %%
print('\nMissing Values')
print(df.isnull().sum())
# Out:
# Missing Values
# Country name                    0
# Regional indicator              0
# Ladder score                    0
# upperwhisker                    0
# lowerwhisker                    0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
print('clean missing values:\n')
df_clean = df.dropna()
print(df_clean)
# Out:
# clean missing values:
#
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...

# %%
print('After clean missing values:')
print(df_clean.isnull().sum())
# Out:
# After clean missing values:
# Country name                    0
# Regional indicator              0
# Ladder score                    0
# upperwhisker                    0
# lowerwhisker                    0
# Log GDP per capita              0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Dystopia + residual             0
# dtype: int64

# %%
print('Summary Statistics:')
print(df_clean.describe())
# Out:
# Summary Statistics:
#        Ladder score  upperwhisker  lowerwhisker  Log GDP per capita  \
# count    140.000000    140.000000    140.000000          140.000000
# mean       5.530893      5.644057      5.417700            1.378807
# std        1.181247      1.165108      1.198051            0.425098
# min        1.721000      1.775000      1.667000            0.000000
# 25%        4.631750      4.762250      4.503750            1.077750
# 50%        5.800500      5.911000      5.676500            1.431500
# 75%        6.426250      6.515250      6.338250            1.741500
# max        7.741000      7.815000      7.667000            2.141000
#
#        Social support  Healthy life expectancy  Freedom to make life choices  \
# count      140.000000               140.000000                    140.000000
# mean         1.134329                 0.520886                      0.620621
# std          0.333317                 0.164923                      0.162492
# ...

# %%
top10 = df_clean.nlargest(10,'Ladder score')[['Country name','Ladder score']]
print('\nTop 10 Happiest Countries:\n')
print(top10)
# Out:
# Top 10 Happiest Countries:
#
#   Country name  Ladder score
# 0      Finland         7.741
# 1      Denmark         7.583
# 2      Iceland         7.525
# 3       Sweden         7.344
# 4       Israel         7.341
# 5  Netherlands         7.319
# 6       Norway         7.302
# 7   Luxembourg         7.122
# 8  Switzerland         7.060
# 9    Australia         7.057

# %%
bottom10 = df_clean.nsmallest(10,'Ladder score')[['Country name','Ladder score']]
print('Bottom 10 Least Happy Countries:\n')
print(bottom10)
# Out:
# Bottom 10 Least Happy Countries:
#
#          Country name  Ladder score
# 142       Afghanistan         1.721
# 141           Lebanon         2.707
# 140           Lesotho         3.186
# 139      Sierra Leone         3.245
# 138  Congo (Kinshasa)         3.295
# 137          Zimbabwe         3.341
# 136          Botswana         3.383
# 135            Malawi         3.421
# 133            Zambia         3.502
# 134          Eswatini         3.502

# %%
regional_avg = df_clean.groupby('Regional indicator')['Ladder score'].mean().sort_values(ascending=False)
print('Regional Average Happiness:\n')
print(regional_avg)
# Out:
# Regional Average Happiness:
#
# Regional indicator
# North America and ANZ                 6.927750
# Western Europe                        6.841650
# Central and Eastern Europe            6.170941
# Latin America and Caribbean           6.143368
# East Asia                             5.934333
# Commonwealth of Independent States    5.567111
# Southeast Asia                        5.551889
# Middle East and North Africa          5.170733
# Sub-Saharan Africa                    4.329686
# South Asia                            3.895667
# Name: Ladder score, dtype: float64

# %%
country_gdp = df_clean.loc[df['Log GDP per capita'].idxmax(),['Country name','Log GDP per capita']]
print('Country with Highest GDP:\n')
print(country_gdp)
# Out:
# Country with Highest GDP:
#
# Country name          Luxembourg
# Log GDP per capita         2.141
# Name: 7, dtype: object

# %%
country_gdp = df_clean.loc[df['Log GDP per capita'].idxmin(),['Country name','Log GDP per capita']]
print('Country with Lowest GDP:\n')
print(country_gdp)
# Out:
# Country with Lowest GDP:
#
# Country name          Venezuela
# Log GDP per capita          0.0
# Name: 78, dtype: object

# %%
country = df_clean.loc[df_clean["Perceptions of corruption"].idxmin(), ["Country name", "Perceptions of corruption"]]
print('Country with Lowest Perception of Corruption:\n')
print(country)
# Out:
# Country with Lowest Perception of Corruption:
#
# Country name                 Bosnia and Herzegovina
# Perceptions of corruption                       0.0
# Name: 64, dtype: object

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=top10,x='Country name',y='Ladder score',color='black',edgecolor='red')
plt.title('Top 10 Happiest Countries 2024')
plt.xlabel('Country Name')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# Note:
#
# This bar chart presents the Top 10 Happiest Countries in the year 2024 based on their Happiness Score.
#
# The X-axis shows the country names (Finland, Denmark, Iceland, Sweden, Israel, Netherlands, Norway, Luxembourg, Switzerland, Australia).
#
# The Y-axis represents the Happiness Score (ranging between 7.0 and 7.8).
#
# Finland ranks the highest with a happiness score close to 7.8.
#
# The remaining countries have very similar scores, all above 7.0, showing that these countries have a high quality of life, social support, and overall happiness.
#
# So, the chart highlights that Finland, Denmark, and Iceland are leading, while the rest are also among the happiest nations in 2024.

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=bottom10,x='Country name',y='Ladder score',color='gray',edgecolor='black')
plt.title('Bottom 10 Least Happy Countries 2024')
plt.xlabel('Country Name')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# Note:
#
# This bar chart presents the Bottom 10 Least Happy Countries in 2024 based on their Happiness Score.
#
# The X-axis lists the countries: Afghanistan, Lebanon, Lesotho, Sierra Leone, Congo (Kinshasa), Zimbabwe, Botswana, Malawi, Zambia, and Eswatini.
#
# The Y-axis shows their Happiness Scores ranging between 1.7 and 3.5.
#
# Afghanistan is the least happy country with the lowest score (around 1.7).
#
# Other countries like Lebanon, Lesotho, and Sierra Leone also have low scores under 3.0.
#
# Even the “highest” among this group (Zambia and Eswatini) have scores only around 3.5, which is much lower compared to the world’s happiest countries (above 7.0).
#
# This chart highlights poverty, instability, and low quality of life as key reasons for low happiness in these countries.

# %%
regional_avg = df_clean.groupby('Regional indicator')['Ladder score'].mean().sort_values()

plt.figure(figsize=(10,6))
regional_avg.plot(kind='barh',color='purple',edgecolor='black')
plt.title('Regional Happiness Averages')
plt.xlabel('Average Happiness Score')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# Note:
#
# This horizontal bar chart shows the average happiness scores by region in 2024.
#
# The X-axis represents the average happiness score.
#
# The Y-axis lists different regions of the world.
#
# North America and ANZ (Australia & New Zealand) has the highest happiness average (close to 7.0), followed by Western Europe.
#
# Regions like Central and Eastern Europe, Latin America, and East Asia have moderate scores (around 6.0).
#
# South Asia (around 4.0) and Sub-Saharan Africa (around 4.3) show the lowest average happiness levels.
#
# This chart highlights that developed regions generally report higher happiness, while developing regions face challenges leading to lower happiness levels.

# %%
plt.figure(figsize=(8,6))
plt.scatter(df_clean['Log GDP per capita'],df_clean['Ladder score'],alpha=0.6)
plt.title('GDP vs Ladder Score')
plt.xlabel('GDP per capita')
plt.ylabel('Ladder Score')
plt.show()

# %% [markdown]
# Note:
#
# Highest GDP: Luxembourg (2.14)
#
# Relationship: Higher GDP → Higher Happiness Score (in general).
#
# “આ ચાર્ટ બતાવે છે કે એક દેશમાં જેટલો વધારે GDP per capita હોય છે, તેટલું વધારે દેશના લોકો ખુશ રહેવાની શક્યતા હોય છે. એટલે કે, આવક અને આર્થિક સુખાકારી વધતા લોકોના જીવનનું સ્તર સુધરે છે અને તેઓ વધુ ખુશ રહે છે. પરંતુ એક હદ પછી માત્ર GDP જ ખુશી વધારવામાં પૂરતો નથી — સમાજમાંથી મળતો આધાર, આરોગ્ય, સ્વતંત્રતા અને ભ્રષ્ટાચારનું ઓછું પ્રમાણ પણ ખુશીને અસર કરે છે.”

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_clean,x='Log GDP per capita',y='Ladder score',hue='Regional indicator')
plt.title('GDP vs Happiness Score by Region')
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

# %% [markdown]
# Note:
#
# આ ચાર્ટ બતાવે છે કે એકસરખા GDP ધરાવતા પ્રદેશોમાં પણ સુખાકારીનો સ્તર અલગ હોઈ શકે છે. કેટલાક પ્રદેશોમાં ઓછા GDP હોવા છતાં લોકો વધારે ખુશ છે કારણ કે ત્યાં Social support, Freedom અને Governance મજબૂત છે. બીજી તરફ, કેટલાક પ્રદેશોમાં GDP વધારે હોવા છતાં સુખાકારી ઓછું છે. એટલે GDP મહત્વનું છે, પરંતુ પ્રદેશની સંસ્કૃતિ, સમાજ અને નીતિઓ પણ લોકોની ખુશીને અસર કરે છે.”

# %%
region_counts = df_clean['Regional indicator'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(region_counts,labels=region_counts.index,autopct='%1.1f%%',startangle=140,shadow=True)
plt.title('Percentage of Countries by Region')
plt.show()

# %% [markdown]
# Note:
#
# “આ ચાર્ટ બતાવે છે કે કુલ 143 દેશોમાંથી કયા પ્રદેશમાં કેટલા ટકા દેશો આવે છે. ઉદાહરણ તરીકે, Sub-Saharan Africa માં સૌથી વધારે દેશો છે, જ્યારે North America અથવા Australia જેવા પ્રદેશોમાં બહુ ઓછા દેશો છે. એટલે દરેક પ્રદેશનું પ્રતિનિધિત્વ જુદું છે, અને આથી વૈશ્વિક એનાલિસિસ કરતી વખતે પ્રદેશના વજનને ધ્યાનમાં રાખવું પડે છે.

# %%
top5 = df_clean.nlargest(5,'Ladder score')[['Country name','Ladder score']]
plt.figure(figsize=(7,7))
color=['blue','purple','gray','orange','green']
plt.pie(top5['Ladder score'],labels=top5['Country name'],autopct='%1.1f%%',startangle=120,colors=color,shadow=True)
plt.title("Top 5 Happiest Countries (Share of Scores)")
plt.show()

# %% [markdown]
# Note:
#
# “આ ચાર્ટ બતાવે છે કે દુનિયાના Top 5 સૌથી ખુશ દેશોના Happiness Score નો ભાગ કેટલો છે. એટલે કે, થોડા જ દેશો સમગ્ર વિશ્વની સરેરાશ ખુશીમાં મોટો ફાળો આપે છે. ઉદાહરણ તરીકે Finland, Denmark, Iceland, Israel અને Netherlands ટોચ પર છે અને તેમની પાસે Global Happiness માં નોંધપાત્ર share છે.”

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df_clean,x='Social support',y='Ladder score')
plt.title('Social Support vs Happiness Score')
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# Note:
#
# “આ ચાર્ટ બતાવે છે કે જે દેશોમાં લોકોને એકબીજાનો સામાજિક આધાર વધારે મળે છે, ત્યાં લોકો વધારે ખુશ રહે છે. એટલે કે, જો પરિવાર, મિત્રો કે સમાજનો સહારો મજબૂત હોય તો જીવન સંતોષ અને ખુશીનું સ્તર પણ ઊંચું હોય છે.”
